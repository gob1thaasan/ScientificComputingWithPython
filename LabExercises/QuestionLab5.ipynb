# %% [markdown]
# **Scientific Computation (MKP3303)**
#
#
# > R.U.Gobithaasan (2021). Scientific Computing, Lectures for Undergraduate Degree Program B.Sc (Applied Mathematics), Faculty of Ocean Engineering Technology & Informatics, University Malaysia Terengganu.
# https://sites.google.com/site/gobithaasan/LearnTeach
#
# <p align="center">
#      © 2021 R.U. Gobithaasan All Rights Reserved.
#
# </p>

# %% [markdown]
# **Lab 3: Numbers, Expressions and Functions**

# %% [markdown]
# ## Fill up the following declaration details:
# **I certify that this report is my own work, based on my personal study and/or research. I also certify that this report has not previously been submitted for assessment in any other unit, and that I have not copied in part or whole or otherwise plagiarised the work of other students and/or persons.**
# - Name:
# - Matrix Number:
# - Date:

# %% [markdown]
# ## General Instruction:
# Let say your matrix number is S54321. For computation below, ignore the first letter and use your matrix number by letting $\mathbf{(\alpha , \beta, \gamma, \kappa, \lambda) =(5,4,3,2,1)}$. Hence replace explicitly the values of greek letters as $\alpha = 5, \beta = 4, \gamma = 3, \kappa = 2, \lambda =1$.
#
#
# For example:
#
# **Q0.** Compute $(\beta * \gamma * \kappa)+{\lambda})$:

# %%
(4*3*2)+1
# Out:
# 25

# %% [markdown]
# ## Name your file as follows before submiting via epembelajaran.umt.edu.my
# - save as **matrixnumber-labnumber.ipynb**: for example **S54321-LAB5.ipynb**

# %% [markdown]
# # LAB 5 QUESTIONS

# %% [markdown]
# **Q0.**  Import NumPy module below as np and print out the version you're running:

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt

# %matplotlib inline
print(mpl.__version__)
np.__version__
# Out:
# 3.4.1
# '1.20.2'

# %% [markdown]
# ## PART 1: Two Dimensional

# %% [markdown]
# **Q1**. Write a function using `def` for each $y_i$
#
#  $$
#  y_1 = \alpha e^x \\
#  y_2 = \beta x \\
#  y_3 = \gamma ln(x)
#  $$
#
#  where `e` is the exponential function,`ln` is the natural logarithm and $x \in [-2,2]$.

# %% [markdown]
#  **Q2**. Plot the following graphs in a sample plot with colors and labels as shown.

# %%
x = np.linspace(-2, 2, 100)
# Out:
# <ipython-input-3-7b6999bd4ff4>:8: RuntimeWarning: invalid value encountered in log
#   return 3*np.log(x)

# %% [markdown]
# **Q3**. Plot the points at $x=0.5$ on the same plot

# %%
x = np.linspace(-2, 2, 100)
# Out:
# <ipython-input-3-7b6999bd4ff4>:8: RuntimeWarning: invalid value encountered in log
#   return 3*np.log(x)

# %% [markdown]
# ---
# First represent the function $g(x) = \gamma x^3 - \lambda x$, and its derivatives as `g` and `gp` with `def`. Next Create two axes in a figure and plot the following for $x \in [-2,2]$:
#
#  **Q4**.  Axis 1: Draw a curve in plane $g(x) = \gamma x^3 - \lambda x$ and, roughly identify the intersection of this curve on x-axis.

# %%
def g(x):
    return 3* (x**3) - 2*x

# %% [markdown]
#  **Q5**.  Axis 2: Draw its derivative $g'(x)$ and roughly estimate its inflection point and label this point on the graph. TIPS: An inflection point occurs at  $g'(x) = 0$.

# %% [markdown]
#  **Q6**. Make a new plot. Draw a dotted tangent line passing through $g(1.5)$ in red.
#
#  TIPS:
#  - The tangent line is $t(x) = g'(x_1)(x-x_1) + g(x_1)$.

# %% [markdown]
# ---
# Let two functions:
#
# $$
# L_1:  x_1 - \gamma x_2 = -1 \\
# L_2: \beta x_1  + \kappa x_2 = 13
# $$

# %% [markdown]
# We can represent a system of (linear) equations above in a matrix form of $A.x =b$, where the constants $\beta$, $\gamma$ and $\kappa$ are obtained from your matrix numbers. Answer the following questions based on this matrix:

# %% [markdown]
# **Q7**. Represent matrix A  and b as and store as `A` and `b`, respectively. TIPS: use numpy array function.

# %%
A =
b = np.array([[-1],[13]])
print(b)
# Out:
# [[-1]
#  [13]]

# %% [markdown]
# **Q8**. Compute the determinant of matrix A denoted $|A|$, and store it as `ADet`. TIPS: use `linalg.det(A)` function to compute.

# %%
ADet = 
print(ADet)
# Out:
# 14.0

# %% [markdown]
# **Q9**. If the determinant $|A|= 0$, then the matrix is singular. Identify if matrix A is singular. Singular matrices has no inverse! In case, you bump into a singular matrix after substitution your matrix number into $A$, try using $\alpha \text{or } \kappa$ to reconstruct $A$ to obtain a nonsingular matrix.

# %%
ADet==0
# Out:
# False

# %% [markdown]
# **Q10**. If $|A| \neq 0$, show that the the dot product of $A$ and $A^{-1}$ equals to an identity matrix. TIPS: use `linalg.inv(A)`

# %%
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %% [markdown]
# **Q11**. If $|A| \neq 0$, there exits a unique solution. Solve the system $A.x =b$ using the function `linalg.solve` in numpy.

# %%
x1s,x2s =
# Out:
# [2.64285714]
# [1.21428571]

# %% [markdown]
# **Q12**. In this step, you will visually check your answer. Given
# $$L_1:  x_2 = (x_1 + 1)/\gamma \\
# L_2:  x_2 = (13 -\beta x_1)/\kappa
# $$
# plot the two equations $L_1 \text{and } L_2$ above that makes the system $A.x = b$ using `matplotlib` and also plot the computed intersection of this two equations with a point.

# %%
ax.set_title("$x_1$ versus $x_2$ " )
ax.set_xlabel("$x_1$")
ax.set_ylabel("$x_2$")
ax.legend()
fig.tight_layout();

# %% [markdown]
# ***

# %% [markdown]
# ## PART 1: Three Dimensional Plot

# %% [markdown]
# ***

# %% [markdown]
# Let a linear system with $A.x = b$ defined as follows:
#
# $$
# \begin{equation}
# 	A_{3 \times 3}
#  = \begin{bmatrix}
# 	  0 & 0 & a_{13} \\
# 	  0 & -6 & a_{23} \\
# 	  3 & -7 & a_{33}
# 	\end{bmatrix}
# \end{equation}
# $$
#
# $$
# \begin{equation}
# 	x_{3 \times 1}
#  = \begin{bmatrix}
# 	  x_1  \\
# 	  x_2  \\
# 	  x_3
# 	\end{bmatrix}
# \end{equation}
# $$
# $$
# \begin{equation}
# 	b_{3 \times 1}
#  = \begin{bmatrix}
# 	  -1  \\
# 	  13  \\
# 	  \kappa
# 	\end{bmatrix}
# \end{equation}
# $$
# where $$\mathbf{(a_{13}, a_{23},a_{33})=(\alpha , \beta, \gamma)}$$

# %% [markdown]
# **Q13.** Represent marix A and b using numpy array:

# %%
print(A)
print(b)
# Out:
# [[ 0  0  5]
#  [ 0 -6  4]
#  [ 3 -7  3]]
# [[-1]
#  [13]
#  [ 2]]

# %% [markdown]
# **Q14.** Solve the system using `linalg.solve(A,b)`

# %%
x1s,x2s,x3s = 
print(x1s)
print(x2s)
print(x3s)
# Out:
# [-4.5]
# [-2.3]
# [-0.2]

# %%
# Out:
# array([[-4.5],
#        [-2.3],
#        [-0.2]])

# %% [markdown]
# **Q15.** Write all the equations in the system above using `def`:
# $$L_1:  x_3 = - 1/\alpha \\
# L_2:  x_3 = (13 + 6 x_2)/\beta \\
# L_3:  x_3 = (-2 + 3 x_1 + 7 x_2)/\gamma \\
# $$

# %% [markdown]
# **Q16.** Plot all the equations in the system above in a three dimensional space using `plot_surface` and show the solution as a point in this space.

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

x1 = x2 = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x1, x2)




ax.legend()
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_zlabel('$x_3$')
    
ax.view_init(elev=10., azim=-55)

# %% [markdown]
# **Q17.** Plot all the equations in the system above in a three dimensional space using `plot_wireframe` and show the solution as a point in this space.

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

x1 = x2 = np.linspace(-10, 10, 100)
X, Y = np.meshgrid(x1, x2)



ax.legend()
ax.set_xlabel('$x_1$')
ax.set_ylabel('$x_2$')
ax.set_zlabel('$x_3$')
    
ax.view_init(elev=5., azim=5)

# %% [markdown]
# ## BONUS:

# %% [markdown]
# Below is a python code to draw the famous fractal which you can read by clciking on: [Mandelbrot Set](https://en.wikipedia.org/wiki/Mandelbrot_set).

# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy import newaxis

#to ignore warnings
import warnings
warnings.filterwarnings("ignore")

def compute_mandelbrot(N_max, threshold, nx, ny):
    
    # A grid of c-values
    x = np.linspace(-2, 1, nx)
    y = np.linspace(-1.5, 1.5, ny)
    c = x[:,newaxis] + 1j*y[newaxis,:]
    
    # Mandelbrot iteration
    z = c
    for j in range(N_max):
        z = z**2 + c
        mandelbrot_set = (abs(z) < threshold)
    
    return mandelbrot_set

# %% [markdown]
# - You may create different visualization stages stages by controling static number of iterations per pixel by controlling the $x_i$ values in
# > compute_mandelbrot($x_1$, $x_2$, $x_3$, $x_4$)

# %%
mandelbrotSet = compute_mandelbrot(50, 50., 600, 400)
plt.imshow(mandelbrotSet.T, extent=[-2, 1, -1.5, 1.5])
plt.show()

# %% [markdown]
# **Q** Read about the mathematics of Mandelbrot set and understand the given code above. Explain based on your understanding the computation of Mandelbrot set in the markdown blank given below:

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Mandelbrot Set:</b> Write your explanation and the mathematics behind Mandelbrot set below:
# </div>

# %% [markdown]
# **Q** Create varius visualization stages by giving various values of $x_i$ in
# > compute_mandelbrot($x_1$, $x_2$, $x_3$, $x_4$)

# %% [markdown]
# # LAB 6 QUESTIONS

# %% [markdown]
# ---
#  QUESTION LAB 6 Will be added next week
#
# ---

# %% [markdown]
# ## PART 1: TIME SERIES

# %% [markdown]
# ## PART 2: INTERACTIVE PLOT

# %% [markdown]
# **Q** Will be added next week

# %% [markdown]
# ## PART 3: HIGHER DIMENSION PLOT

# %% [markdown]
# **Q** Will be added next week
