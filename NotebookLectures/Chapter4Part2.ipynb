# %% [markdown]
# **Scientific Computation (MKP3303)**
#
#
# > R.U.Gobithaasan (2021). Scientific Computing, Lectures for Undergraduate Degree Program B.Sc (Applied Mathematics), Faculty of Ocean Engineering Technology & Informatics,, University Malaysia Terengganu.
# https://sites.google.com/site/gobithaasan/LearnTeach
#
# <p align="center">
#      © 2021 R.U. Gobithaasan All Rights Reserved.
#
# </p>

# %% [markdown]
# **Chapter 4: Data Visualization**
#
# **Static Visualization: (MatPlotLib, Pandas, Seaborn. plotnine)**
#
# 1. 2D: Two-dimensional plot (Plane)
# 2. 3D: Three-dimensional plot (Space)
# 3. Time Series Visualization
#
# **Interactive Visualization: (Bokeh, Plotly)**
#
# 4. 2D: Two-dimensional plot (Plane)
# 5. 3D: Three-dimensional plot (Space)
#
# **Higher dimension Visualization**
#
# 6. Dimension Reduction
#
#
# References:
# - [SciPi Lecture Notes](http://scipy-lectures.org/)
# - [Python Data Analysis Library: Pandas](https://pandas.pydata.org/)
#
# 1.  [Matplotlib: Visualization with Python](https://matplotlib.org/)
#
# - [Matplotlib: CHEAT-SHEET: Main Source](https://github.com/matplotlib/cheatsheets)
# - [Handout Beginner](ref//handout-beginner.pdf)
# - [Handout Intermediate](ref//handout-intermediate.pdf)
# - [Handout Tips](ref//handout-tips.pdf)
#
#
# 2. [Seaborn: statistical data visualization](https://seaborn.pydata.org/)
# 3. [Plotly: Python Open Source Graphing Library](https://plotly.com/python/)
#
# 4. - Robert Johansson, Numerical Python: Scientific Computing and Data Science Applications with Numpy, SciPy and Matplotlib (2019, Apress).
# >Source code listings for [Numerical Python - A Practical Techniques Approach for Industry](http://www.apress.com/9781484205549) (ISBN 978-1-484205-54-9). The source code listings can be downloaded from http://www.apress.com/9781484205549

# %% [markdown]
# # Static Visualization:

# %% [markdown]
# ## Time series
#
# - with Pandas, Seaborn & plotnine
#
# - Read more [Working with pandas: Time series](https://pandas.pydata.org/docs/getting_started/intro_tutorials/09_timeseries.html)

# %% [markdown]
# -  In mathematics, a [time series](https://en.wikipedia.org/wiki/Time_series) is a series of data points indexed (or listed or graphed) in time order. Most commonly, a time series is a sequence taken at successive equally spaced points in time. Thus it is a sequence of discrete-time data. Examples of time series are daily rainfall and the daily closing value of the KLCI index.
#
# - In a broader context, a signal which may change over time (temporal signal) or as a function of space coordinates (spatial signal). Rainfalls can be thought as temporal signal in one-dimension and black & white images as spatial signal in two dimensions.

# %%
import pandas as pd
pd.__version__
# Out:
# '1.2.4'

# %%
import matplotlib as mpl
import pandas as pd
import numpy as np

# %% [markdown]
# #### Time
# - Time data type in Python
# - Read [datetime](https://www.w3schools.com/python/python_datetime.asp)

# %%
import datetime as dt
x = dt.datetime.now()
print(x) # Python version of date and time
print(x.strftime("%c")) #Local version of date and time
print(x.year)
print(x.strftime("%A"))
# Out:
# 2021-05-04 14:37:04.507971
# Tue May  4 14:37:04 2021
# 2021
# Tuesday

# %% [markdown]
# - Indexed by time (day)

# %%
time1 = pd.date_range("2021-5-1","2021-5-31", periods = 31)
print(type(time1))
time1.view
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
# <bound method Index.view of DatetimeIndex(['2021-05-01', '2021-05-02', '2021-05-03', '2021-05-04',
#                '2021-05-05', '2021-05-06', '2021-05-07', '2021-05-08',
#                '2021-05-09', '2021-05-10', '2021-05-11', '2021-05-12',
#                '2021-05-13', '2021-05-14', '2021-05-15', '2021-05-16',
#                '2021-05-17', '2021-05-18', '2021-05-19', '2021-05-20',
#                '2021-05-21', '2021-05-22', '2021-05-23', '2021-05-24',
#                '2021-05-25', '2021-05-26', '2021-05-27', '2021-05-28',
#                '2021-05-29', '2021-05-30', '2021-05-31'],
#               dtype='datetime64[ns]', freq=None)>

# %% [markdown]
# - Indexed by time (hour)

# %%
time2 = pd.date_range("2021-5-1 05:00","2021-5-1 19:00", freq = "H" )
print(type(time2))
time1.view
# Out:
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>
# <bound method Index.view of DatetimeIndex(['2021-05-01', '2021-05-02', '2021-05-03', '2021-05-04',
#                '2021-05-05', '2021-05-06', '2021-05-07', '2021-05-08',
#                '2021-05-09', '2021-05-10', '2021-05-11', '2021-05-12',
#                '2021-05-13', '2021-05-14', '2021-05-15', '2021-05-16',
#                '2021-05-17', '2021-05-18', '2021-05-19', '2021-05-20',
#                '2021-05-21', '2021-05-22', '2021-05-23', '2021-05-24',
#                '2021-05-25', '2021-05-26', '2021-05-27', '2021-05-28',
#                '2021-05-29', '2021-05-30', '2021-05-31'],
#               dtype='datetime64[ns]', freq=None)>

# %% [markdown]
# - creating dataset indexed by time (day)

# %%
x = np.random.randint(200,size = 31)
x
# Out:
# array([ 34,  20, 175, 142,  38, 173,  90, 163,  16,  56,   8, 156,  80,
#        125,  24,  90, 185, 188,  30,   3,  39,  43, 158, 129, 191, 119,
#        126, 159,   3, 102,  39])

# %%
sample1 = pd.Series(x, index=pd.date_range("2021-5-1","2021-5-31", freq = "D"))
sample1.head(10)
# Out:
# 2021-05-01     34
# 2021-05-02     20
# 2021-05-03    175
# 2021-05-04    142
# 2021-05-05     38
# 2021-05-06    173
# 2021-05-07     90
# 2021-05-08    163
# 2021-05-09     16
# 2021-05-10     56
# Freq: D, dtype: int32

# %%
sample1.index
# Out:
# DatetimeIndex(['2021-05-01', '2021-05-02', '2021-05-03', '2021-05-04',
#                '2021-05-05', '2021-05-06', '2021-05-07', '2021-05-08',
#                '2021-05-09', '2021-05-10', '2021-05-11', '2021-05-12',
#                '2021-05-13', '2021-05-14', '2021-05-15', '2021-05-16',
#                '2021-05-17', '2021-05-18', '2021-05-19', '2021-05-20',
#                '2021-05-21', '2021-05-22', '2021-05-23', '2021-05-24',
#                '2021-05-25', '2021-05-26', '2021-05-27', '2021-05-28',
#                '2021-05-29', '2021-05-30', '2021-05-31'],
#               dtype='datetime64[ns]', freq='D')

# %% [markdown]
# - Accessing data based on time

# %%
sample1["2021-05-09"]
# Out:
# 16

# %% [markdown]
# - Accessing data based on its numbering index

# %%
sample1.index[29]
# Out:
# Timestamp('2021-05-30 00:00:00', freq='D')

# %%
sample1.index[29].day,sample1.index[29].month, sample1.index[29].year
# Out:
# (30, 5, 2021)

# %%
import matplotlib.pyplot as plt 
fig, axes = plt.subplots(1, 2, figsize=(12, 3.5))

sample1.plot(ax=axes[0], kind='line', title="line graph")
sample1.plot(ax=axes[1], kind='bar', title="bar chart")

fig.tight_layout()

# %% [markdown]
# - Bar plot: changing the x labels as years

# %%
sample2 = pd.Series(x, index=pd.date_range("2021-5-1","2021-5-31", freq = "D").day)

# %%
import matplotlib.pyplot as plt 
fig, axes = plt.subplots(1, 2, figsize=(12, 3.5))

sample1.plot(ax=axes[0], kind='line', title="line graph")
sample2.plot(ax=axes[1], kind='bar', title="bar chart")

fig.tight_layout()

# %% [markdown]
# ### Example using population **without time as index**

# %%
populations1 = pd.read_csv("data/populations.csv")
populations1.head(3)
# Out:
#    # year     hare    lynx  carrot
# 0    1900  30000.0  4000.0   48300
# 1    1901  47200.0  6100.0   48200
# 2    1902  70200.0  9800.0   41500

# %% [markdown]
# ---

# %%
print(populations1.index)
print(populations1.columns)
# Out:
# RangeIndex(start=0, stop=21, step=1)
# Index(['# year', 'hare', 'lynx', 'carrot'], dtype='object')

# %%
populations1[["# year","lynx"]].head(3)
# Out:
#    # year    lynx
# 0    1900  4000.0
# 1    1901  6100.0
# 2    1902  9800.0

# %%
species = populations1[["hare","lynx","carrot"]]
species.head(3)
# Out:
#       hare    lynx  carrot
# 0  30000.0  4000.0   48300
# 1  47200.0  6100.0   48200
# 2  70200.0  9800.0   41500

# %%
import matplotlib.pyplot as plt 
fig, axes = plt.subplots(1, 3, figsize=(12, 3.5))

species.plot(ax=axes[0], kind='line', title="line graph")
species.plot(ax=axes[1], kind='box', title="boxplot")
species.plot(ax=axes[2], kind='bar', title="bar chart")

fig.tight_layout()
#fig.savefig("populations.pdf")
#fig.savefig("populations.png")

# %% [markdown]
# ## Converting into time series: using year as index

# %%
pd.date_range("1900","1921", freq = "Y")
# Out:
# DatetimeIndex(['1900-12-31', '1901-12-31', '1902-12-31', '1903-12-31',
#                '1904-12-31', '1905-12-31', '1906-12-31', '1907-12-31',
#                '1908-12-31', '1909-12-31', '1910-12-31', '1911-12-31',
#                '1912-12-31', '1913-12-31', '1914-12-31', '1915-12-31',
#                '1916-12-31', '1917-12-31', '1918-12-31', '1919-12-31',
#                '1920-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
pd.date_range("1900","1921", freq = "Y").year
# Out:
# Int64Index([1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910,
#             1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920],
#            dtype='int64')

# %%
populations2 = pd.read_csv("data/populations.csv")
populations2 = (
    populations2.filter([
        'hare',
        'lynx',
        'carrot'
    ]).set_index(pd.date_range("1900","1921", freq = "Y"))
)

# %%
populations2.index
# Out:
# DatetimeIndex(['1900-12-31', '1901-12-31', '1902-12-31', '1903-12-31',
#                '1904-12-31', '1905-12-31', '1906-12-31', '1907-12-31',
#                '1908-12-31', '1909-12-31', '1910-12-31', '1911-12-31',
#                '1912-12-31', '1913-12-31', '1914-12-31', '1915-12-31',
#                '1916-12-31', '1917-12-31', '1918-12-31', '1919-12-31',
#                '1920-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
populations2.index.year
# Out:
# Int64Index([1900, 1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910,
#             1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920],
#            dtype='int64')

# %%
populations2.loc["1915"]
# Out:
#                hare     lynx  carrot
# 1915-12-31  19500.0  51100.0   39000

# %%
populations2.loc[("1910","carrot")]
# Out:
# 1910-12-31    46000
# Freq: A-DEC, Name: carrot, dtype: int64

# %%
populations2.describe()
# Out:
#                hare          lynx        carrot
# count     21.000000     21.000000     21.000000
# mean   34080.952381  20166.666667  42400.000000
# std    21413.981859  16655.999920   3404.555771
# min     7600.000000   4000.000000  36700.000000
# 25%    19500.000000   8600.000000  39800.000000
# 50%    25400.000000  12300.000000  41800.000000
# 75%    47200.000000  29700.000000  44500.000000
# max    77400.000000  59400.000000  48300.000000

# %%
import matplotlib.pyplot as plt 

fig, axes = plt.subplots(1, 3, figsize=(12, 3.5))

populations2.plot(ax=axes[0], kind='line', title="line graph")
populations2.plot(ax=axes[1], kind='box', title="boxplot")
populations2.plot(ax=axes[2], kind='bar', title="bar chart" )

fig.tight_layout()
#fig.savefig("populations.pdf")
#fig.savefig("populations.png")

# %% [markdown]
# ## Using Seaborn
# - Seaborn is a Python data visualization library based on matplotlib. It provides a high-level interface for drawing attractive and informative statistical graphics.
# - [Seaborn: statistical data visualization](https://seaborn.pydata.org/)

# %%
#!pip install seaborn

# %%
#import seaborn as sns 
import seaborn as sns
sns.__version__
# Out:
# '0.11.1'

# %%
round(populations2.describe(),)
# Out:
#           hare     lynx   carrot
# count     21.0     21.0     21.0
# mean   34081.0  20167.0  42400.0
# std    21414.0  16656.0   3405.0
# min     7600.0   4000.0  36700.0
# 25%    19500.0   8600.0  39800.0
# 50%    25400.0  12300.0  41800.0
# 75%    47200.0  29700.0  44500.0
# max    77400.0  59400.0  48300.0

# %% [markdown]
# - Visualizing Distribution

# %%
sns.histplot(populations2, bins=50);

# %%
sns.jointplot(data=populations2)

# %% [markdown]
# - histogram plot

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3 , figsize=(8, 4))

sns.boxplot(data = populations2, ax=ax1, palette="pastel")
sns.violinplot(data = populations2, ax=ax2, palette="vlag")
sns.stripplot( data=populations2, ax=ax1, size=4, color=".3", linewidth=0)
sns.stripplot( data=populations2, ax=ax3, size=4, color=".3", linewidth=0)

fig.tight_layout()
#fig.savefig("seaborn-boxplot-violinplot.pdf")

# %% [markdown]
# - Visualizing  relationships between two variables

# %%
sns.relplot(x="hare", y="carrot", data=populations2);

# %%
sns.relplot(x="hare", y="lynx", data=populations2);

# %%
sns.relplot(x="lynx", y="carrot",kind="line", 
            height=3, aspect=1, linewidth=1.5,  data=populations2);

# %%
sns.relplot(x="hare", y="lynx", hue="carrot",
            data=populations2)

# %%
sns.relplot(x="hare", y="lynx", size="carrot",
            data=populations2)

# %% [markdown]
# - Assigning a second variable to y, however, will plot a bivariate distribution.
# - A bivariate histogram bins the data within rectangles that tile the plot and then shows the count of observations within each rectangle with the fill color (analagous to a heatmap()).

# %%
sns.displot(populations2, x="hare", y="lynx", cbar=True)

# %% [markdown]
# -Similarly, a bivariate KDE plot smoothes the (x, y) observations with a 2D Gaussian. The default representation then shows the contours of the 2D density:

# %%
sns.displot(populations2, x="hare", y="lynx", kind="kde", rug=True)

# %%
g = sns.PairGrid(populations2)
g.map_upper(sns.histplot)
g.map_lower(sns.kdeplot, fill=True)
g.map_diag(sns.histplot, kde=True)

# %% [markdown]
# # Lecture notes to be continued...

# %% [markdown]
# ## Using `plotnine`

# %% [markdown]
# ---
# `ggplot` is a Python implementation of the book **Grammar of Graphics** which is implemented in R (ggp2plot).
# - **The basic building blocks are of [Grammar of Graphics](https://link.springer.com/book/10.1007%2F0-387-28695-0) are:**
#
# 1. **data:** The data + a set of aesthetic mappings that describing variables mapping
# 2. **geom:** Geometric objects, represent what you actually see on the plot: points, lines, polygons, etc.
# 3. **stats:** Statistical transformations, summarise data in many useful ways.
# 4. **scale:** The scales map values in the data space to values in an aesthetic space
# 5. **coord:** A coordinate system, describes how data coordinates are mapped to the plane of the graphic.
# 6. **facet:** A faceting specification describes how to break up the data into subsets for plotting individual set
#
#
# `plotnine` is a Grammar of Graphics implementation for Python by Hassan Kibirige.
#
# [REF1](https://monashdatafluency.github.io/python-workshop-base/modules/plotting_with_ggplot/)
# [REF2](https://towardsdatascience.com/how-to-use-ggplot2-in-python-74ab8adec129)
# [REF3](https://towardsdatascience.com/data-visualization-in-python-like-in-rs-ggplot2-bc62f8debbf5)
# [REF4](https://datascienceworkshops.com/blog/plotnine-grammar-of-graphics-for-python/)

# %%
#!pip install plotnine

# %%
from plotnine import *
# %matplotlib inline

# %%
ggplot(populations2) +\
geom_point(mapping=aes(x="hare", y="carrot"))
# Out:
# <ggplot: (149775813985)>

# %% [markdown]
# # Interactive Visualization

# %% [markdown]
# - You do not need to run `%matplotlib inline` for interactive figure generation, figures will be generated in a separate window.

# %% [markdown]
# # Higher dimension visualization

# %% [markdown]
# - A three dimensional object: when you cut through a three dimensional object, you obtain a plane with bounded area.
# - Whatever that we can plot in a space $\mathbb{R}^4$.
# - similar analogy applies for higher dimension!
